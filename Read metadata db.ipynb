# %% [markdown]
# # Read metadata database
#
# From s3://multimedia-commons/tools/etc/yfcc100m_dataset.sql

# %%
import sqlite3
import pandas as pd

# %%
db_path = '/mnt/efs/yfcc100m_dataset.sql'

# %%
con = sqlite3.connect(db_path)
cur = con.cursor()

# %% [markdown]
# ## Schema

# %%
# https://stackoverflow.com/a/41007154/11262633
newline_indent = '\n   '
con.text_factory = str

result = cur.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
table_names = sorted(list(zip(*result))[0])
print ("\ntables are:"+newline_indent+newline_indent.join(table_names))

for table_name in table_names:
    result = cur.execute("PRAGMA table_info('%s')" % table_name).fetchall()
    column_names = list(zip(*result))[1]
    print (("\ncolumn names for %s:" % table_name)
           +newline_indent
           +(newline_indent.join(column_names)))

print ("\nComplete")
# Out:
# tables are:
#    yfcc100m_dataset
#
# column names for yfcc100m_dataset:
#    photoid
#    uid
#    unickname
#    datetaken
#    dateuploaded
#    capturedevice
#    title
#    description
#    usertags
#    machinetags
#    longitude
#    latitude
#    accuracy
#    pageurl
#    downloadurl
#    licensename
#    licenseurl
#    serverid
#    farmid
#    secret
#    secretoriginal
#    ext
#    marker
#
# Complete

# %% [markdown]
# ## Sample data

# %%
df = pd.read_sql_query('select * from yfcc100m_dataset limit 10', con)
df.iloc[:10]
# Out:
#    photoid              uid           unickname              datetaken  \
# 0    28605  34427465634@N01               Emily  2004-04-30 23:33:51.0
# 1    29060  34427466731@N01            striatic  2004-05-02 17:12:01.0
# 2    29205  34427469121@N01              George  2004-05-03 10:16:04.0
# 3    29209  34427469121@N01              George  2004-05-03 10:16:06.0
# 4    29294  37912375204@N01  Schlomo+Rabinowitz  2004-05-01 16:49:37.0
# 5    29604  37912375204@N01  Schlomo+Rabinowitz  2004-04-23 15:51:18.0
# 6    29812  35034347309@N01        Josh+Mishell  2004-05-05 16:38:20.0
# 7    29814  35034347309@N01        Josh+Mishell  2004-05-05 16:38:21.0
# 8    29857  34427465504@N01             Trinity  2004-05-05 20:01:24.0
# 9    29872  34427465504@N01             Trinity  2004-05-05 21:30:05.0
#
#   dateuploaded capturedevice                           title  \
# 0   1083393231                                   C%26H+ascii
# 1   1083543121                Christmas+Panorama+%7Bnotes%7D
# 2   1083604564                                       La+Luna
# 3   1083604566                                From+the+entry
# 4   1083625746   SONY+DSC-V1                          detail
# 5   1083731910   SONY+DSC-V1                      meandwayne
# 6   1083800300                                    butterfly3
# 7   1083800301                                    butterfly5
# 8   1083812484                                     ninja+bee
# 9   1083817805                              bruise+5%2F2%2F4
#
#                                          description  \
# 0
# 1  a+link+to+a+much+higher+resolution+version%2C+...
# 2                            From+outside+my+window.
# 3          This+is+what+you+see+-+with+no+furniture.
# 4       detail+of+painting+by+Romanowski+and+friends
# 5                            on+his+rockstar+tourbus
# 6                       butterfy+pavilion%2C+denver.
# 7                       butterfy+pavilion%2C+denver.
# 8  %3Ca+href%3D%22http%3A%2F%2Fwww.burningprose.c...
# 9  I+got+this+bruise+at+work...wonder+if+I+can+ge...
#
#                                             usertags machinetags  ...  \
# 0                                                                 ...
# 1  alberta,canada,christmas,edmonton,family,indoo...              ...
# 2                                        moon,vankie              ...
# 3                                          apartment              ...
# 4        abstract,graffiti,painting,romanowski,urban              ...
# 5       friend,me,mirror,notes,schlomo,unfound,wayne              ...
# 6                            butterfly,photos+i+took              ...
# 7                            butterfly,photos+i+took              ...
# 8                                               2004              ...
# 9                       2004,bruise,me,photo,unfound              ...
#
#                                              pageurl  \
# 0  http://www.flickr.com/photos/34427465634@N01/2...
# 1  http://www.flickr.com/photos/34427466731@N01/2...
# 2  http://www.flickr.com/photos/34427469121@N01/2...
# 3  http://www.flickr.com/photos/34427469121@N01/2...
# 4  http://www.flickr.com/photos/37912375204@N01/2...
# 5  http://www.flickr.com/photos/37912375204@N01/2...
# 6  http://www.flickr.com/photos/35034347309@N01/2...
# 7  http://www.flickr.com/photos/35034347309@N01/2...
# 8  http://www.flickr.com/photos/34427465504@N01/2...
# 9  http://www.flickr.com/photos/34427465504@N01/2...
#
#                                          downloadurl  \
# 0  http://farm1.staticflickr.com/1/28605_d138ef7b...
# 1  http://farm1.staticflickr.com/1/29060_e90c2a0c...
# 2  http://farm1.staticflickr.com/1/29205_64d31038...
# 3  http://farm1.staticflickr.com/1/29209_6d55fad2...
# 4  http://farm1.staticflickr.com/1/29294_a0fc568d...
# 5  http://farm1.staticflickr.com/1/29604_878d5a7d...
# 6  http://farm1.staticflickr.com/1/29812_a4b0eac0...
# 7  http://farm1.staticflickr.com/1/29814_04e328d9...
# 8  http://farm1.staticflickr.com/1/29857_67ac7fa6...
# 9  http://farm1.staticflickr.com/1/29872_c787b1b0...
#
#                                     licensename  \
# 0  Attribution-NonCommercial-ShareAlike License
# 1                           Attribution License
# 2    Attribution-NonCommercial-NoDerivs License
# 3    Attribution-NonCommercial-NoDerivs License
# 4    Attribution-NonCommercial-NoDerivs License
# 5    Attribution-NonCommercial-NoDerivs License
# 6    Attribution-NonCommercial-NoDerivs License
# 7    Attribution-NonCommercial-NoDerivs License
# 8                Attribution-ShareAlike License
# 9                Attribution-ShareAlike License
#
#                                           licenseurl serverid farmid  \
# 0  http://creativecommons.org/licenses/by-nc-sa/2.0/        1      1
# 1        http://creativecommons.org/licenses/by/2.0/        1      1
# 2  http://creativecommons.org/licenses/by-nc-nd/2.0/        1      1
# 3  http://creativecommons.org/licenses/by-nc-nd/2.0/        1      1
# 4  http://creativecommons.org/licenses/by-nc-nd/2.0/        1      1
# 5  http://creativecommons.org/licenses/by-nc-nd/2.0/        1      1
# 6  http://creativecommons.org/licenses/by-nc-nd/2.0/        1      1
# 7  http://creativecommons.org/licenses/by-nc-nd/2.0/        1      1
# 8     http://creativecommons.org/licenses/by-sa/2.0/        1      1
# 9     http://creativecommons.org/licenses/by-sa/2.0/        1      1
#
#        secret  secretoriginal  ext marker
# 0  d138ef7b45      d138ef7b45  jpg      0
# 1  e90c2a0c1c      e90c2a0c1c  jpg      0
# 2  64d31038b1      64d31038b1  jpg      0
# 3  6d55fad203      6d55fad203  jpg      0
# 4  a0fc568df3      a0fc568df3  jpg      0
# 5  878d5a7ddd      878d5a7ddd  jpg      0
# 6  a4b0eac007      a4b0eac007  jpg      0
# 7  04e328d9a0      04e328d9a0  jpg      0
# 8  67ac7fa6e4      67ac7fa6e4  jpg      0
# 9  c787b1b056      c787b1b056  jpg      0
#
# [10 rows x 23 columns]

# %% [markdown]
# ## # Rows in table

# %%
result = cur.execute('select count(*) from yfcc100m_dataset').fetchall()
print(result)
