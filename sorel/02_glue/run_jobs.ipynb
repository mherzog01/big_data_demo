# %% [markdown]
# # Runs Sorel job
#
# Captures job initiation information

# %%
import boto3
import time
import datetime
from collections import Counter

# %%
def logmsg(msg):
    print(msg)

def logmsg01(msg):
    logmsg(f'{datetime.datetime.now():%Y-%m-%d %H:%M:%S}:  {msg}')

# %%
FILTER_SIZE = 2
MAX_CONCUR_JOBS = 16
NUM_JOBS_TO_RUN = 256

TARG_BUCKET = 'sorel-20m-demo'

JOB_NAME = 'transfer-sorel-binaries'

# %%
session = boto3.Session(profile_name='personal')

# %% [markdown]
# Clean out target

# %%
def get_obj_to_delete(prefix='output'):
    return s3.Bucket(TARG_BUCKET).objects.filter(Prefix=prefix)

def num_obj(objects):
    return len([o for o in objects])

# Power shell command:
#   ('0001', '0002', '001','002','003','3') | %{write-host $_;aws s3 --profile personal rm s3://sorel-20m-demo/output/$_/ --recursive}
s3 = session.resource('s3')

objects = get_obj_to_delete()
logmsg(f'Keys to delete:  {num_obj(objects)}')
while True:
    # Will only delete 1000 objects
    response = objects.delete()
    if 'Errors' in response:
        logmsg(f'Errors encountered when performing delete')
        logmsg(response['Errors'])
        break
    objects = get_obj_to_delete()
    if num_obj(objects) == 0:
        break
    logmsg(f'{num_obj(objects)} remain to delete')
logmsg('Delete complete')
# Out:
# Keys to delete:  0
# Delete complete

# %%
padding = FILTER_SIZE

job_status = {f'{i:0{padding}x}':{'JobRunId':None, 'JobRunState':None} for i in range(NUM_JOBS_TO_RUN)}
num_success = 0

# %%
glue_client = session.client('glue', region_name='us-east-1')

def run_job(filter_chars):
    response = glue_client.start_job_run(
                    JobName=JOB_NAME,
                    Arguments={
                        "--enable-auto-scaling":"true",
                        "--enable-metrics":"true",
                        "--enable-spark-ui":"true",
                        "--spark-event-logs-path":'s3://aws-glue-assets-883375387566-us-east-1/sparkHistoryLogs/',
                        "--enable-continuous-cloudwatch-log":"true",
                        "--filter_chars":filter_chars
                    },
                    WorkerType='G.1X',
                    NumberOfWorkers=5,
                )
    job_status[filter_chars] = {'JobRunId':response["JobRunId"], 'JobRunState':'RUNNING'}
    logmsg01(f'Creating job with filter_chars={filter_chars}, JobRunId={response["JobRunId"]}')
    return response

# %%
logmsg01('Process begins')

while True:
    # Update the status of each job that is running
    num_running = 0
    for filter_chars, job_info in job_status.items():
        if job_info['JobRunState'] == 'RUNNING':
            response = glue_client.get_job_run(JobName=JOB_NAME, RunId=job_info['JobRunId'])
            job_run = response['JobRun']
            run_status =   {'JobRunId': job_run['Id'],
                            'JobRunState': job_run['JobRunState'], 
                            'StartedOn':job_run['StartedOn'], 
                            'LastModifiedOn': job_run['LastModifiedOn'], 
                            'ExecutionTime': job_run['ExecutionTime']}
            job_info['JobRunState'] = run_status['JobRunState']

        if job_info['JobRunState'] == 'RUNNING':
            num_running += 1

    # Start any jobs that are required and within the MAX_CONCUR_JOBS
    for filter_chars, job_info in job_status.items():
        if job_info['JobRunState'] in ['SUCCEEDED', 'RUNNING']:
            continue
        if num_running >= MAX_CONCUR_JOBS:
            break  
        # Start the current job
        response = run_job(filter_chars)
        num_running += 1

    status_summary = Counter(d['JobRunState'] for d in job_status.values())
    
    num_success = status_summary.get('SUCCEEDED', 0)
    if num_success >= NUM_JOBS_TO_RUN:
        break
    
    logmsg01(status_summary)
    time.sleep(60)
    
status_summary = Counter(d['JobRunState'] for d in run_status.values())
logmsg(status_summary)
logmsg01('Process complete')
# Out:
# 2023-03-20 04:21:49:  Process begins
# 2023-03-20 04:22:34:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:23:36:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:24:37:  Counter({None: 240, 'RUNNING': 16})

# %%
job_status
# Out:
# {'00': {'JobRunId': 'jr_c89c574b75d24f9b67af9a1d3024bdf024cc5ee3937a5e90046057dcfd3d36bf',
#   'JobRunState': 'RUNNING'},
#  '01': {'JobRunId': 'jr_e8e65f3b9c60cf73e98a01879d02ce86084d0dfe550cb9d8eec1f36042b7a457',
#   'JobRunState': 'RUNNING'},
#  '02': {'JobRunId': 'jr_cf3e9a24f2e9a95d6f609be3a91ee70f11821ef8787d9c95456fe3d0bc93d95e',
#   'JobRunState': 'RUNNING'},
#  '03': {'JobRunId': 'jr_940220d9eabfa8dd6d62c8c592fa49a12733c7b8eafbc2f8204413847823e91c',
#   'JobRunState': 'RUNNING'},
#  '04': {'JobRunId': 'jr_ea7b7efe0b35b98e18818508eedb89fe9956756dad7656068b60a51fccbd9ef8',
#   'JobRunState': 'RUNNING'},
#  '05': {'JobRunId': 'jr_c3e3b931cdc13e068b867819a71fcfdac10fcb5cd93ae56d1fa46ae352579d0d',
#   'JobRunState': 'RUNNING'},
#  '06': {'JobRunId': 'jr_e1d939f2305f205b7c8a7765f8af028a1de74be8cb79c0123c74ebfa1b58d7a0',
#   'JobRunState': 'RUNNING'},
#  '07': {'JobRunId': 'jr_4196417312da1fd30cbb9171fac169a117ce732f0aa9f601ff62c7bda226818a',
#   'JobRunState': 'RUNNING'},
#  '08': {'JobRunId': 'jr_de761424fdff76b12c83086b23c599eb371a5e45817d041b340a16da1dd49812',
#   'JobRunState': 'RUNNING'},
#  '09': {'JobRunId': 'jr_41ce285cef1ae2f56c45fa66b6f41d87aaa031b69f2c476aad2903cf27f69698',
#   'JobRunState': 'RUNNING'},
#  '0a': {'JobRunId': 'jr_be32dafc73b03a86a84026abadae3837602168167e908802f25048b801b67059',
#   'JobRunState': 'RUNNING'},
#  '0b': {'JobRunId': 'jr_d86db5209e3c7733be54e32d2dd2452ebaedf988a13923b4dde8629bff59f938',
#   'JobRunState': 'RUNNING'},
#  '0c': {'JobRunId': 'jr_2d96e6edf315a80c320fbe6130d7565899dcf6a0a2fbb31ca75a14669ceef966',
#   'JobRunState': 'RUNNING'},
#  '0d': {'JobRunId': 'jr_ae905666bc1f4c1c6b0b2a9ef8a398a0325ce23c4f4f905b6591672b3dfa58a8',
#   'JobRunState': 'RUNNING'},
#  '0e': {'JobRunId': 'jr_dee1ccff7d89d3fb0bd6fed21c4b6d464d2e43bfe4f4ee9de492379384232c7f',
#   'JobRunState': 'RUNNING'},
#  '0f': {'JobRunId': 'jr_bac369922a37df6879d680aa5615dd2a5ae305caecf1fd5cb883ebf9773593f5',
#   'JobRunState': 'RUNNING'},
#  '10': {'JobRunId': None, 'JobRunState': None},
#  '11': {'JobRunId': None, 'JobRunState': None},
#  '12': {'JobRunId': None, 'JobRunState': None},
#  '13': {'JobRunId': None, 'JobRunState': None},
#  '14': {'JobRunId': None, 'JobRunState': None},
#  '15': {'JobRunId': None, 'JobRunState': None},
#  '16': {'JobRunId': None, 'JobRunState': None},
#  '17': {'JobRunId': None, 'JobRunState': None},
#  '18': {'JobRunId': None, 'JobRunState': None},
#  '19': {'JobRunId': None, 'JobRunState': None},
#  '1a': {'JobRunId': None, 'JobRunState': None},
#  '1b': {'JobRunId': None, 'JobRunState': None},
#  '1c': {'JobRunId': None, 'JobRunState': None},
#  '1d': {'JobRunId': None, 'JobRunState': None},
#  '1e': {'JobRunId': None, 'JobRunState': None},
#  '1f': {'JobRunId': None, 'JobRunState': None},
#  '20': {'JobRunId': None, 'JobRunState': None},
#  '21': {'JobRunId': None, 'JobRunState': None},
#  '22': {'JobRunId': None, 'JobRunState': None},
#  '23': {'JobRunId': None, 'JobRunState': None},
#  '24': {'JobRunId': None, 'JobRunState': None},
#  '25': {'JobRunId': None, 'JobRunState': None},
#  '26': {'JobRunId': None, 'JobRunState': None},
#  '27': {'JobRunId': None, 'JobRunState': None},
#  '28': {'JobRunId': None, 'JobRunState': None},
#  '29': {'JobRunId': None, 'JobRunState': None},
#  '2a': {'JobRunId': None, 'JobRunState': None},
#  '2b': {'JobRunId': None, 'JobRunState': None},
#  '2c': {'JobRunId': None, 'JobRunState': None},
#  '2d': {'JobRunId': None, 'JobRunState': None},
#  '2e': {'JobRunId': None, 'JobRunState': None},
#  '2f': {'JobRunId': None, 'JobRunState': None},
#  '30': {'JobRunId': None, 'JobRunState': None},
#  '31': {'JobRunId': None, 'JobRunState': None},
#  '32': {'JobRunId': None, 'JobRunState': None},
#  '33': {'JobRunId': None, 'JobRunState': None},
#  '34': {'JobRunId': None, 'JobRunState': None},
#  '35': {'JobRunId': None, 'JobRunState': None},
#  '36': {'JobRunId': None, 'JobRunState': None},
#  '37': {'JobRunId': None, 'JobRunState': None},
#  '38': {'JobRunId': None, 'JobRunState': None},
#  '39': {'JobRunId': None, 'JobRunState': None},
#  '3a': {'JobRunId': None, 'JobRunState': None},
#  '3b': {'JobRunId': None, 'JobRunState': None},
#  '3c': {'JobRunId': None, 'JobRunState': None},
#  '3d': {'JobRunId': None, 'JobRunState': None},
#  '3e': {'JobRunId': None, 'JobRunState': None},
#  '3f': {'JobRunId': None, 'JobRunState': None},
#  '40': {'JobRunId': None, 'JobRunState': None},
#  '41': {'JobRunId': None, 'JobRunState': None},
#  '42': {'JobRunId': None, 'JobRunState': None},
#  '43': {'JobRunId': None, 'JobRunState': None},
#  '44': {'JobRunId': None, 'JobRunState': None},
#  '45': {'JobRunId': None, 'JobRunState': None},
#  '46': {'JobRunId': None, 'JobRunState': None},
#  '47': {'JobRunId': None, 'JobRunState': None},
#  '48': {'JobRunId': None, 'JobRunState': None},
#  '49': {'JobRunId': None, 'JobRunState': None},
#  '4a': {'JobRunId': None, 'JobRunState': None},
#  '4b': {'JobRunId': None, 'JobRunState': None},
#  '4c': {'JobRunId': None, 'JobRunState': None},
#  '4d': {'JobRunId': None, 'JobRunState': None},
#  '4e': {'JobRunId': None, 'JobRunState': None},
#  '4f': {'JobRunId': None, 'JobRunState': None},
#  '50': {'JobRunId': None, 'JobRunState': None},
#  '51': {'JobRunId': None, 'JobRunState': None},
#  '52': {'JobRunId': None, 'JobRunState': None},
#  '53': {'JobRunId': None, 'JobRunState': None},
#  '54': {'JobRunId': None, 'JobRunState': None},
#  '55': {'JobRunId': None, 'JobRunState': None},
#  '56': {'JobRunId': None, 'JobRunState': None},
#  '57': {'JobRunId': None, 'JobRunState': None},
#  '58': {'JobRunId': None, 'JobRunState': None},
#  '59': {'JobRunId': None, 'JobRunState': None},
#  '5a': {'JobRunId': None, 'JobRunState': None},
#  '5b': {'JobRunId': None, 'JobRunState': None},
#  '5c': {'JobRunId': None, 'JobRunState': None},
#  '5d': {'JobRunId': None, 'JobRunState': None},
#  '5e': {'JobRunId': None, 'JobRunState': None},
#  '5f': {'JobRunId': None, 'JobRunState': None},
#  '60': {'JobRunId': None, 'JobRunState': None},
#  '61': {'JobRunId': None, 'JobRunState': None},
#  '62': {'JobRunId': None, 'JobRunState': None},
#  '63': {'JobRunId': None, 'JobRunState': None},
#  '64': {'JobRunId': None, 'JobRunState': None},
#  '65': {'JobRunId': None, 'JobRunState': None},
#  '66': {'JobRunId': None, 'JobRunState': None},
#  '67': {'JobRunId': None, 'JobRunState': None},
#  '68': {'JobRunId': None, 'JobRunState': None},
#  '69': {'JobRunId': None, 'JobRunState': None},
#  '6a': {'JobRunId': None, 'JobRunState': None},
#  '6b': {'JobRunId': None, 'JobRunState': None},
#  '6c': {'JobRunId': None, 'JobRunState': None},
#  '6d': {'JobRunId': None, 'JobRunState': None},
#  '6e': {'JobRunId': None, 'JobRunState': None},
#  '6f': {'JobRunId': None, 'JobRunState': None},
#  '70': {'JobRunId': None, 'JobRunState': None},
#  '71': {'JobRunId': None, 'JobRunState': None},
#  '72': {'JobRunId': None, 'JobRunState': None},
#  '73': {'JobRunId': None, 'JobRunState': None},
#  '74': {'JobRunId': None, 'JobRunState': None},
#  '75': {'JobRunId': None, 'JobRunState': None},
#  '76': {'JobRunId': None, 'JobRunState': None},
#  '77': {'JobRunId': None, 'JobRunState': None},
#  '78': {'JobRunId': None, 'JobRunState': None},
#  '79': {'JobRunId': None, 'JobRunState': None},
#  '7a': {'JobRunId': None, 'JobRunState': None},
#  '7b': {'JobRunId': None, 'JobRunState': None},
#  '7c': {'JobRunId': None, 'JobRunState': None},
#  '7d': {'JobRunId': None, 'JobRunState': None},
#  '7e': {'JobRunId': None, 'JobRunState': None},
#  '7f': {'JobRunId': None, 'JobRunState': None},
#  '80': {'JobRunId': None, 'JobRunState': None},
#  '81': {'JobRunId': None, 'JobRunState': None},
#  '82': {'JobRunId': None, 'JobRunState': None},
#  '83': {'JobRunId': None, 'JobRunState': None},
#  '84': {'JobRunId': None, 'JobRunState': None},
#  '85': {'JobRunId': None, 'JobRunState': None},
#  '86': {'JobRunId': None, 'JobRunState': None},
#  '87': {'JobRunId': None, 'JobRunState': None},
#  '88': {'JobRunId': None, 'JobRunState': None},
#  '89': {'JobRunId': None, 'JobRunState': None},
#  '8a': {'JobRunId': None, 'JobRunState': None},
#  '8b': {'JobRunId': None, 'JobRunState': None},
#  '8c': {'JobRunId': None, 'JobRunState': None},
#  '8d': {'JobRunId': None, 'JobRunState': None},
#  '8e': {'JobRunId': None, 'JobRunState': None},
#  '8f': {'JobRunId': None, 'JobRunState': None},
#  '90': {'JobRunId': None, 'JobRunState': None},
#  '91': {'JobRunId': None, 'JobRunState': None},
#  '92': {'JobRunId': None, 'JobRunState': None},
#  '93': {'JobRunId': None, 'JobRunState': None},
#  '94': {'JobRunId': None, 'JobRunState': None},
#  '95': {'JobRunId': None, 'JobRunState': None},
#  '96': {'JobRunId': None, 'JobRunState': None},
#  '97': {'JobRunId': None, 'JobRunState': None},
#  '98': {'JobRunId': None, 'JobRunState': None},
#  '99': {'JobRunId': None, 'JobRunState': None},
#  '9a': {'JobRunId': None, 'JobRunState': None},
#  '9b': {'JobRunId': None, 'JobRunState': None},
#  '9c': {'JobRunId': None, 'JobRunState': None},
#  '9d': {'JobRunId': None, 'JobRunState': None},
#  '9e': {'JobRunId': None, 'JobRunState': None},
#  '9f': {'JobRunId': None, 'JobRunState': None},
#  'a0': {'JobRunId': None, 'JobRunState': None},
#  'a1': {'JobRunId': None, 'JobRunState': None},
#  'a2': {'JobRunId': None, 'JobRunState': None},
#  'a3': {'JobRunId': None, 'JobRunState': None},
#  'a4': {'JobRunId': None, 'JobRunState': None},
#  'a5': {'JobRunId': None, 'JobRunState': None},
#  'a6': {'JobRunId': None, 'JobRunState': None},
#  'a7': {'JobRunId': None, 'JobRunState': None},
#  'a8': {'JobRunId': None, 'JobRunState': None},
#  'a9': {'JobRunId': None, 'JobRunState': None},
#  'aa': {'JobRunId': None, 'JobRunState': None},
#  'ab': {'JobRunId': None, 'JobRunState': None},
#  'ac': {'JobRunId': None, 'JobRunState': None},
#  'ad': {'JobRunId': None, 'JobRunState': None},
#  'ae': {'JobRunId': None, 'JobRunState': None},
#  'af': {'JobRunId': None, 'JobRunState': None},
#  'b0': {'JobRunId': None, 'JobRunState': None},
#  'b1': {'JobRunId': None, 'JobRunState': None},
#  'b2': {'JobRunId': None, 'JobRunState': None},
#  'b3': {'JobRunId': None, 'JobRunState': None},
#  'b4': {'JobRunId': None, 'JobRunState': None},
#  'b5': {'JobRunId': None, 'JobRunState': None},
#  'b6': {'JobRunId': None, 'JobRunState': None},
#  'b7': {'JobRunId': None, 'JobRunState': None},
#  'b8': {'JobRunId': None, 'JobRunState': None},
#  'b9': {'JobRunId': None, 'JobRunState': None},
#  'ba': {'JobRunId': None, 'JobRunState': None},
#  'bb': {'JobRunId': None, 'JobRunState': None},
#  'bc': {'JobRunId': None, 'JobRunState': None},
#  'bd': {'JobRunId': None, 'JobRunState': None},
#  'be': {'JobRunId': None, 'JobRunState': None},
#  'bf': {'JobRunId': None, 'JobRunState': None},
#  'c0': {'JobRunId': None, 'JobRunState': None},
#  'c1': {'JobRunId': None, 'JobRunState': None},
#  'c2': {'JobRunId': None, 'JobRunState': None},
#  'c3': {'JobRunId': None, 'JobRunState': None},
#  'c4': {'JobRunId': None, 'JobRunState': None},
#  'c5': {'JobRunId': None, 'JobRunState': None},
#  'c6': {'JobRunId': None, 'JobRunState': None},
#  'c7': {'JobRunId': None, 'JobRunState': None},
#  'c8': {'JobRunId': None, 'JobRunState': None},
#  'c9': {'JobRunId': None, 'JobRunState': None},
#  'ca': {'JobRunId': None, 'JobRunState': None},
#  'cb': {'JobRunId': None, 'JobRunState': None},
#  'cc': {'JobRunId': None, 'JobRunState': None},
#  'cd': {'JobRunId': None, 'JobRunState': None},
#  'ce': {'JobRunId': None, 'JobRunState': None},
#  'cf': {'JobRunId': None, 'JobRunState': None},
#  'd0': {'JobRunId': None, 'JobRunState': None},
#  'd1': {'JobRunId': None, 'JobRunState': None},
#  'd2': {'JobRunId': None, 'JobRunState': None},
#  'd3': {'JobRunId': None, 'JobRunState': None},
#  'd4': {'JobRunId': None, 'JobRunState': None},
#  'd5': {'JobRunId': None, 'JobRunState': None},
#  'd6': {'JobRunId': None, 'JobRunState': None},
#  'd7': {'JobRunId': None, 'JobRunState': None},
#  'd8': {'JobRunId': None, 'JobRunState': None},
#  'd9': {'JobRunId': None, 'JobRunState': None},
#  'da': {'JobRunId': None, 'JobRunState': None},
#  'db': {'JobRunId': None, 'JobRunState': None},
#  'dc': {'JobRunId': None, 'JobRunState': None},
#  'dd': {'JobRunId': None, 'JobRunState': None},
#  'de': {'JobRunId': None, 'JobRunState': None},
#  'df': {'JobRunId': None, 'JobRunState': None},
#  'e0': {'JobRunId': None, 'JobRunState': None},
#  'e1': {'JobRunId': None, 'JobRunState': None},
#  'e2': {'JobRunId': None, 'JobRunState': None},
#  'e3': {'JobRunId': None, 'JobRunState': None},
#  'e4': {'JobRunId': None, 'JobRunState': None},
#  'e5': {'JobRunId': None, 'JobRunState': None},
#  'e6': {'JobRunId': None, 'JobRunState': None},
#  'e7': {'JobRunId': None, 'JobRunState': None},
#  'e8': {'JobRunId': None, 'JobRunState': None},
#  'e9': {'JobRunId': None, 'JobRunState': None},
#  'ea': {'JobRunId': None, 'JobRunState': None},
#  'eb': {'JobRunId': None, 'JobRunState': None},
#  'ec': {'JobRunId': None, 'JobRunState': None},
#  'ed': {'JobRunId': None, 'JobRunState': None},
#  'ee': {'JobRunId': None, 'JobRunState': None},
#  'ef': {'JobRunId': None, 'JobRunState': None},
#  'f0': {'JobRunId': None, 'JobRunState': None},
#  'f1': {'JobRunId': None, 'JobRunState': None},
#  'f2': {'JobRunId': None, 'JobRunState': None},
#  'f3': {'JobRunId': None, 'JobRunState': None},
#  'f4': {'JobRunId': None, 'JobRunState': None},
#  'f5': {'JobRunId': None, 'JobRunState': None},
#  'f6': {'JobRunId': None, 'JobRunState': None},
#  'f7': {'JobRunId': None, 'JobRunState': None},
#  'f8': {'JobRunId': None, 'JobRunState': None},
#  'f9': {'JobRunId': None, 'JobRunState': None},
#  'fa': {'JobRunId': None, 'JobRunState': None},
#  'fb': {'JobRunId': None, 'JobRunState': None},
#  'fc': {'JobRunId': None, 'JobRunState': None},
#  'fd': {'JobRunId': None, 'JobRunState': None},
#  'fe': {'JobRunId': None, 'JobRunState': None},
#  'ff': {'JobRunId': None, 'JobRunState': None}}
