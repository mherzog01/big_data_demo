# %% [markdown]
# # Runs Sorel job
#
# Captures job initiation information

# %%
import boto3
import time
import datetime
from collections import Counter

# %%
def logmsg(msg):
    print(msg)

def logmsg01(msg):
    logmsg(f'{datetime.datetime.now():%Y-%m-%d %H:%M:%S}:  {msg}')

# %%
FILTER_SIZE = 2
MAX_CONCUR_JOBS = 16
NUM_JOBS_TO_RUN = 256

TARG_BUCKET = 'sorel-20m-demo'

JOB_NAME = 'transfer-sorel-binaries'

# %%
session = boto3.Session(profile_name='personal')

# %% [markdown]
# Clean out target

# %%
def get_obj_to_delete(prefix='output'):
    return s3.Bucket(TARG_BUCKET).objects.filter(Prefix=prefix)

def num_obj(objects):
    return len([o for o in objects])

# Power shell command:
#   ('0001', '0002', '001','002','003','3') | %{write-host $_;aws s3 --profile personal rm s3://sorel-20m-demo/output/$_/ --recursive}
s3 = session.resource('s3')

objects = get_obj_to_delete()
logmsg(f'Keys to delete:  {num_obj(objects)}')
while True:
    # Will only delete 1000 objects
    response = objects.delete()
    if 'Errors' in response:
        logmsg(f'Errors encountered when performing delete')
        logmsg(response['Errors'])
        break
    objects = get_obj_to_delete()
    if num_obj(objects) == 0:
        break
    logmsg(f'{num_obj(objects)} remain to delete')
logmsg('Delete complete')
# Out:
# Keys to delete:  0
# Delete complete

# %%
padding = FILTER_SIZE

job_status = {f'{i:0{padding}x}':{'JobRunId':None, 'JobRunState':None} for i in range(NUM_JOBS_TO_RUN)}
num_success = 0

# %%
glue_client = session.client('glue', region_name='us-east-1')

def run_job(filter_chars):
    response = glue_client.start_job_run(
                    JobName=JOB_NAME,
                    Arguments={
                        "--enable-auto-scaling":"true",
                        "--enable-metrics":"true",
                        "--enable-spark-ui":"true",
                        "--spark-event-logs-path":'s3://aws-glue-assets-883375387566-us-east-1/sparkHistoryLogs/',
                        "--enable-continuous-cloudwatch-log":"true",
                        "--filter_chars":filter_chars
                    },
                    WorkerType='G.1X',
                    NumberOfWorkers=5,
                )
    job_status[filter_chars] = {'JobRunId':response["JobRunId"], 'JobRunState':'RUNNING'}
    logmsg01(f'Creating job with filter_chars={filter_chars}, JobRunId={response["JobRunId"]}')
    return response

# %%
logmsg01('Process begins')
start_time = datetime.datetime.now()

while True:
    # Update the status of each job that is running
    num_running = 0
    for filter_chars, job_info in job_status.items():
        if job_info['JobRunState'] == 'RUNNING':
            response = glue_client.get_job_run(JobName=JOB_NAME, RunId=job_info['JobRunId'])
            job_run = response['JobRun']
            run_status =   {'JobRunId': job_run['Id'],
                            'JobRunState': job_run['JobRunState'], 
                            'StartedOn':job_run['StartedOn'], 
                            'LastModifiedOn': job_run['LastModifiedOn'], 
                            'ExecutionTime': job_run['ExecutionTime']}
            job_info['JobRunState'] = run_status['JobRunState']

        if job_info['JobRunState'] == 'RUNNING':
            num_running += 1

    # Start any jobs that are required and within the MAX_CONCUR_JOBS
    for filter_chars, job_info in job_status.items():
        if job_info['JobRunState'] in ['SUCCEEDED', 'RUNNING']:
            continue
        if num_running >= MAX_CONCUR_JOBS:
            break  
        # Start an instance of the job for the current parameter
        response = run_job(filter_chars)
        num_running += 1

    status_summary = Counter(d['JobRunState'] for d in job_status.values())
    
    num_success = status_summary.get('SUCCEEDED', 0)
    if num_success >= NUM_JOBS_TO_RUN:
        break
    
    logmsg01(status_summary)
    time.sleep(60)
    
status_summary = Counter(d['JobRunState'] for d in job_status.values())
logmsg01(status_summary)
end_time = datetime.datetime.now()
logmsg(f'Process duration = {end_time - start_time}')
logmsg01('Process complete')
# Out:
# 2023-03-20 04:21:49:  Process begins
# 2023-03-20 04:22:34:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:23:36:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:24:37:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:25:39:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:26:41:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:27:43:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:28:44:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:29:46:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:30:48:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:31:49:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:32:51:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:33:53:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:34:55:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:35:57:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:36:59:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:38:01:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:39:03:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:40:04:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:41:06:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:42:08:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:43:10:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:44:11:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:45:13:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:46:15:  Counter({None: 240, 'RUNNING': 16})
# 2023-03-20 04:47:31:  Creating job with filter_chars=10, JobRunId=jr_aa6265bcb686dfa94c67b7d101c84b95a6b599e6ee181bf2edb4386233dd876c
# 2023-03-20 04:47:31:  Counter({None: 239, 'RUNNING': 16, 'SUCCEEDED': 1})
# 2023-03-20 04:48:40:  Creating job with filter_chars=11, JobRunId=jr_86f0c36c328950e15fb7921f6336c7d82d88c9d09c707d33794458c5a11868fb
# 2023-03-20 04:48:40:  Creating job with filter_chars=12, JobRunId=jr_b0cbdbff42fe9e97e934bf960ecb3964bca6a40cfebec618e9a054b31ddde98b
# 2023-03-20 04:48:41:  Creating job with filter_chars=13, JobRunId=jr_49d175d7391300d33c507e5b5c09fe04017f11565954e28bd807966e8e12892c
# 2023-03-20 04:48:41:  Creating job with filter_chars=14, JobRunId=jr_0e9d10323a808a4a9cb57fdbdb9007ae3805ce8b55010ae76b9502bdfbd23f54
# 2023-03-20 04:48:42:  Creating job with filter_chars=15, JobRunId=jr_16703b98f385c3a578a668769c983f9b92c1b1968c29b06683ba2fd8de6e051e
# 2023-03-20 04:48:42:  Creating job with filter_chars=16, JobRunId=jr_d627f7fa2baf738d58a528c99b34639ddaa1311e57e0a9909e1d1209822ed04a
# 2023-03-20 04:48:42:  Creating job with filter_chars=17, JobRunId=jr_8c186d846618521583f1925682ef04178dda7eaf6d1ce55c2bc0ec964d038d3a
# 2023-03-20 04:48:42:  Creating job with filter_chars=18, JobRunId=jr_3020affb469311a47a76f6b0a142b9c110784b3e2c0fedf48b7954700900f7c4
# 2023-03-20 04:48:42:  Creating job with filter_chars=19, JobRunId=jr_df1bfd70d2c938edee6773ef2460d642d74f7b41b474f6bfd63d145dc87753f7
# 2023-03-20 04:48:42:  Creating job with filter_chars=1a, JobRunId=jr_59f9d7ae38b9f980468fc3e5948b5f3bc6aac122670285469b5d984675a3afca
# 2023-03-20 04:48:43:  Creating job with filter_chars=1b, JobRunId=jr_7dd4c3a2e306d2e5afde0e2e83b970805512bb88ed51c0a4c1f7d61d1c920953
# 2023-03-20 04:48:43:  Counter({None: 228, 'RUNNING': 16, 'SUCCEEDED': 12})
# 2023-03-20 04:49:44:  Creating job with filter_chars=1c, JobRunId=jr_7868c8ac264371b3719a5cd5cd371aaae2bea26d7c08421147111e76512e314a
# 2023-03-20 04:49:45:  Creating job with filter_chars=1d, JobRunId=jr_a1de75ae9e70723e712a410e782dc2cbc0e03892d9a9503da26cdff82beb090e
# 2023-03-20 04:49:45:  Creating job with filter_chars=1e, JobRunId=jr_3c93958301e94df0918ab2e0142e09b369f509391e7e5daad744bdd3a1444ead
# 2023-03-20 04:49:45:  Counter({None: 225, 'RUNNING': 16, 'SUCCEEDED': 15})
# 2023-03-20 04:50:47:  Creating job with filter_chars=1f, JobRunId=jr_96e0256c0cd623998954c397849e1b406e9cc7a251fd8c1c5b319e0efade552e
# 2023-03-20 04:50:47:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:51:48:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:52:59:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:54:01:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:55:03:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:56:05:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:57:07:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:58:08:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 04:59:10:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:00:12:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:01:14:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:02:16:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:03:19:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:04:20:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:05:22:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:06:24:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:07:26:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:08:27:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:09:29:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:10:31:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:11:32:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:12:35:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:13:36:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:14:38:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:15:40:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:16:42:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:17:43:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:18:45:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:19:47:  Counter({None: 224, 'SUCCEEDED': 16, 'RUNNING': 16})
# 2023-03-20 05:20:49:  Creating job with filter_chars=20, JobRunId=jr_c12d58fec768047308b1d62ada07200b80b079b1e5f79e458d7bb24d67e04982
# 2023-03-20 05:20:49:  Counter({None: 223, 'SUCCEEDED': 17, 'RUNNING': 16})
# 2023-03-20 05:21:51:  Creating job with filter_chars=21, JobRunId=jr_3f40ef5ca7301d141e0c744770d6becb9804e198ffc3c73b6f546de867fb56cc
# 2023-03-20 05:21:51:  Creating job with filter_chars=22, JobRunId=jr_ca8dd7283f2ae84a15734d5c722b265cf2060ea89ac5d1cf6792070c3ea7f2d1
# 2023-03-20 05:21:51:  Counter({None: 221, 'SUCCEEDED': 19, 'RUNNING': 16})
# 2023-03-20 05:22:52:  Creating job with filter_chars=23, JobRunId=jr_66c0e6884ef4a1d659d73064a6bcbc7c518e309cb03ee897036506842690acca
# 2023-03-20 05:22:53:  Creating job with filter_chars=24, JobRunId=jr_b57890d46429c0ba88f42d9b1558be86457d2652a90ea76fe38c44d617b149ec
# 2023-03-20 05:22:53:  Creating job with filter_chars=25, JobRunId=jr_b5a709a0afb7040cef6e81e917ef8ba1715f72cc5862859ca8d2205c1da00c84
# 2023-03-20 05:22:53:  Creating job with filter_chars=26, JobRunId=jr_cf9a13bbc094a1b48477929f78690fb44f83caff2997ef1c32c7addc921334a9
# 2023-03-20 05:22:53:  Creating job with filter_chars=27, JobRunId=jr_0401569414f58f8503e183bbe9166ccaca870a1b72e348e3dde15faf2f759739
# 2023-03-20 05:22:53:  Creating job with filter_chars=28, JobRunId=jr_dafbe9d9714cff7278fa9f58cc3fdaff9739da8aca503717c4f5f4450dc5eb0e
# 2023-03-20 05:22:53:  Creating job with filter_chars=29, JobRunId=jr_58a5979d9f1fa9da39768f99cacecfa09513792ff8644deda2bc5987b3230249
# 2023-03-20 05:22:53:  Creating job with filter_chars=2a, JobRunId=jr_ed8944f0d197ed3bf0d424d63d880d8dc54aec4c9aacc2408e33d6b6f2b796b6
# 2023-03-20 05:22:54:  Creating job with filter_chars=2b, JobRunId=jr_68703c78526e6435b6829d2e820532365de81bc3a435228d879270fdd5fc5c2b
# 2023-03-20 05:22:54:  Counter({None: 212, 'SUCCEEDED': 28, 'RUNNING': 16})
# 2023-03-20 05:23:56:  Creating job with filter_chars=2c, JobRunId=jr_31f9faafbad63df94d41d25afb87cb3a322fe44cb18d7fd2c7700cd12fc01566
# 2023-03-20 05:23:56:  Creating job with filter_chars=2d, JobRunId=jr_4ec8dd274e0f2d3b2c0524212ad41772b3bdb02442c557a0a512f1c55f270389
# 2023-03-20 05:23:56:  Creating job with filter_chars=2e, JobRunId=jr_4b14a1919a106c93167ddd3c71cd7de907570801c66af8be99d4221ef7f80007
# 2023-03-20 05:23:56:  Counter({None: 209, 'SUCCEEDED': 31, 'RUNNING': 16})
# 2023-03-20 05:24:58:  Creating job with filter_chars=2f, JobRunId=jr_141fa4e32d35d748736004a4b2cad30a5c9c07a97ee99b877bcd999b72b77394
# 2023-03-20 05:24:58:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:26:00:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:27:02:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:28:04:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:29:05:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:30:08:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:31:09:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:32:12:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:33:14:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:34:16:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:35:18:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:36:20:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:37:21:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:38:23:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:39:25:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:40:26:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:41:28:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:42:30:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:43:31:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:44:33:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:45:35:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:46:37:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:47:39:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:48:41:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:49:42:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:50:44:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:51:46:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:52:48:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:53:49:  Counter({None: 208, 'SUCCEEDED': 32, 'RUNNING': 16})
# 2023-03-20 05:54:51:  Creating job with filter_chars=30, JobRunId=jr_1661962372f3f9aa6b7e6de008ece783d7be7803aeb3e18b9fd0b023bf8c776a
# 2023-03-20 05:54:51:  Creating job with filter_chars=31, JobRunId=jr_ca88cbe0420794437b2e731055b09a3ed9c429b572991ba1014b24d171dc978b
# 2023-03-20 05:54:51:  Counter({None: 206, 'SUCCEEDED': 34, 'RUNNING': 16})
# 2023-03-20 05:55:53:  Creating job with filter_chars=32, JobRunId=jr_2fd3c74e1db4b7d48b0daeabfdd7e6fbbe0b37faf407a128820fe891a80085ce
# 2023-03-20 05:55:53:  Counter({None: 205, 'SUCCEEDED': 35, 'RUNNING': 16})
# 2023-03-20 05:56:55:  Creating job with filter_chars=33, JobRunId=jr_bb1bb7318aa3d4ecde9fb10abdad48ee7463197ba2a14ccdf1aa81604cc62b6c
# 2023-03-20 05:56:55:  Creating job with filter_chars=34, JobRunId=jr_c8f607477da2b00d3fd8dc51df5b06317964177445927d309c56d02a9139a2ee
# 2023-03-20 05:56:55:  Creating job with filter_chars=35, JobRunId=jr_61bfb38f8bec352a84367ebf2a59ae91de9317a613777a4b3288d78abeba5c83
# 2023-03-20 05:56:55:  Creating job with filter_chars=36, JobRunId=jr_1049680f8c5146a75d41559ea2f81de459193ecd728a6b7cb2641769ea4bf53c
# 2023-03-20 05:56:55:  Creating job with filter_chars=37, JobRunId=jr_3e1919c9171c1293adffeadaea31c5cc4241dfdb87f72f334b42be4940ec33b4
# 2023-03-20 05:56:56:  Creating job with filter_chars=38, JobRunId=jr_9d6ef056faae3f8e6a9a549eed8a2c26df400c22b67b83583f354d752e30323f
# 2023-03-20 05:56:56:  Creating job with filter_chars=39, JobRunId=jr_faa38ed815f7290fe519fd43272b4926a6e9b74a58221d5f4374266d8e41a8cf
# 2023-03-20 05:56:56:  Creating job with filter_chars=3a, JobRunId=jr_9a77682ee52866333fabb76ab74152ae970ce385ef7c5f805b36fb53ca7f671e
# 2023-03-20 05:56:56:  Creating job with filter_chars=3b, JobRunId=jr_1baedfed3bdbf3f386aa0c264731a455ec6ba53f60ac35423c99b67a79e61407
# 2023-03-20 05:56:56:  Counter({None: 196, 'SUCCEEDED': 44, 'RUNNING': 16})
# 2023-03-20 05:57:58:  Creating job with filter_chars=3c, JobRunId=jr_0d1520c91b76d398a43a85f21d0a5bfb875b1637e4a860388d3a493228de138f
# 2023-03-20 05:57:58:  Creating job with filter_chars=3d, JobRunId=jr_037a6644d70ac768452207f325e0c218159d49b2c074066a09764f26b17b0723
# 2023-03-20 05:57:58:  Creating job with filter_chars=3e, JobRunId=jr_cf139a392c5739f001469545a1a94f0fb5a64cc7ebad7e95ce7a7ff496cee5ff
# 2023-03-20 05:57:58:  Counter({None: 193, 'SUCCEEDED': 47, 'RUNNING': 16})
# 2023-03-20 05:59:00:  Creating job with filter_chars=3f, JobRunId=jr_bf79708efde8313c3cb116bb478890233074791f8219110575c5d82000728dc0
# 2023-03-20 05:59:00:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:00:02:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:01:04:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:02:07:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:03:09:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:04:10:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:05:12:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:06:14:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:07:16:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:08:18:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:09:20:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:10:22:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:11:24:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:12:26:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:13:28:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:14:29:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:15:32:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:16:33:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:17:35:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:18:37:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:19:39:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:20:40:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:21:42:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:22:44:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:23:45:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:24:47:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:25:49:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:26:50:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:27:52:  Counter({None: 192, 'SUCCEEDED': 48, 'RUNNING': 16})
# 2023-03-20 06:28:54:  Creating job with filter_chars=40, JobRunId=jr_16f3b47f1a23fa3b00f25f0dade8b629caf69f8ea3cd262dac34bec31bb8a9a5
# 2023-03-20 06:28:54:  Creating job with filter_chars=41, JobRunId=jr_e0b7a916c2f712265eb466dc4e19a8029f60e985c87e56d252c20fe8e2e248b3
# 2023-03-20 06:28:54:  Counter({None: 190, 'SUCCEEDED': 50, 'RUNNING': 16})
# 2023-03-20 06:29:56:  Creating job with filter_chars=42, JobRunId=jr_434064870938161cd773e20f96975b9817c26f39985550ffab7a03f5f866f19c
# 2023-03-20 06:29:56:  Counter({None: 189, 'SUCCEEDED': 51, 'RUNNING': 16})
# 2023-03-20 06:30:58:  Creating job with filter_chars=43, JobRunId=jr_fb26f23b9c14e9667863057d399b6ee965108922ce8e32ffe2704aa3137743f3
# 2023-03-20 06:30:58:  Creating job with filter_chars=44, JobRunId=jr_37b2be0f97c426fa394b818069cdd379ea2486a41a28203be0e4f76be10bc869
# 2023-03-20 06:30:58:  Creating job with filter_chars=45, JobRunId=jr_683cf1dd6836ad3e5bb8e69f8f9aff9330559cb21503871540eb02e6b266801b
# 2023-03-20 06:30:58:  Creating job with filter_chars=46, JobRunId=jr_711fa492fc21e37423c9f790e81076a7f90687c1928c10db9491c8298d374c83
# 2023-03-20 06:30:59:  Creating job with filter_chars=47, JobRunId=jr_8d2ec0cfc79b0dee6da450e0abeeb493d38eaffb12db90d6bc9a71d94fedd102
# 2023-03-20 06:30:59:  Creating job with filter_chars=48, JobRunId=jr_e8b42a8139dafb49826f8eb4378a0a18cb7f4c9672ffd5c744f8f6eafc6d709c
# 2023-03-20 06:30:59:  Creating job with filter_chars=49, JobRunId=jr_5821be1e75c75067ae0a07687d49e0bae4273fd96b92d0066d2d52598f6aaa4d
# 2023-03-20 06:30:59:  Creating job with filter_chars=4a, JobRunId=jr_9ad165a6215bd06d3983ecfc77ecfa4951341044b220ff350a393f3bb9322e06
# 2023-03-20 06:30:59:  Creating job with filter_chars=4b, JobRunId=jr_f2b568ffa3519740968c5cfd37e79b1994e4625e2169548346c845d41a5704ff
# 2023-03-20 06:30:59:  Counter({None: 180, 'SUCCEEDED': 60, 'RUNNING': 16})
# 2023-03-20 06:32:01:  Creating job with filter_chars=4c, JobRunId=jr_d39931751ddc1ef48fb9c67fb09c6d2ac8c5377f3403ec0985826228d010a7ba
# 2023-03-20 06:32:01:  Creating job with filter_chars=4d, JobRunId=jr_2fb7046f183735f1c17221db6e78f577e24af6c94d64920628b2392721b2998f
# 2023-03-20 06:32:01:  Creating job with filter_chars=4e, JobRunId=jr_98dd603b038ce59562188bad9bba52183c9bd6397580dcb07031501494be492a
# 2023-03-20 06:32:01:  Counter({None: 177, 'SUCCEEDED': 63, 'RUNNING': 16})
# 2023-03-20 06:33:03:  Counter({None: 177, 'SUCCEEDED': 63, 'RUNNING': 16})
# 2023-03-20 06:34:05:  Counter({None: 177, 'SUCCEEDED': 63, 'RUNNING': 16})
# 2023-03-20 06:35:07:  Counter({None: 177, 'SUCCEEDED': 63, 'RUNNING': 16})
# 2023-03-20 06:36:09:  Creating job with filter_chars=4f, JobRunId=jr_e60ae44489607fad519d446eb00fbea47783a5af6bb30e9d26d55a2fdb180600
# 2023-03-20 06:36:09:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:37:11:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:38:12:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:39:14:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:40:16:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:41:17:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:42:19:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:43:21:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:44:23:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:45:25:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:46:27:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:47:29:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:48:30:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:49:32:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:50:34:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:51:35:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:52:37:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:53:39:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:54:40:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:55:43:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:56:45:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:57:46:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:58:48:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 06:59:50:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 07:00:52:  Counter({None: 176, 'SUCCEEDED': 64, 'RUNNING': 16})
# 2023-03-20 07:01:54:  Creating job with filter_chars=50, JobRunId=jr_df40f42095843f97789f4c0ed88ac583632ffa60eeed61efb3cd949878cb2cb8
# 2023-03-20 07:01:54:  Creating job with filter_chars=51, JobRunId=jr_f151209a6176df834f8ea3ffb9e1322f3ab88604963a99ee8608084b525a2fee
# 2023-03-20 07:01:54:  Counter({None: 174, 'SUCCEEDED': 66, 'RUNNING': 16})
# 2023-03-20 07:02:55:  Counter({None: 174, 'SUCCEEDED': 66, 'RUNNING': 16})
# 2023-03-20 07:03:57:  Creating job with filter_chars=52, JobRunId=jr_72949c378e4ca041f9b94c827612818952280968967623cfbe925c3e44cb4478
# 2023-03-20 07:03:57:  Creating job with filter_chars=53, JobRunId=jr_50f701a9c83c843164c0f7a9aea56802241ec49368bf9097996c55a14a60c52e
# 2023-03-20 07:03:58:  Creating job with filter_chars=54, JobRunId=jr_adc7c73ca50da0c217865ff2f8f02523ce5916732549c7ff904135374a74c5ee
# 2023-03-20 07:03:58:  Counter({None: 171, 'SUCCEEDED': 69, 'RUNNING': 16})
# 2023-03-20 07:04:59:  Creating job with filter_chars=55, JobRunId=jr_7a56229024790d82e5c585ac7e805e6a0c3efb4e2889f3ee36662d8ded121e36
# 2023-03-20 07:04:59:  Creating job with filter_chars=56, JobRunId=jr_50d9774c972a50b99a041111dbe8e94a8cd35e082488fe30e7584ecfc9fcde31
# 2023-03-20 07:05:00:  Creating job with filter_chars=57, JobRunId=jr_80c09ac0c635a38e8ee70232ea0a6fa7fae4aa170a9ca784d44fef4fbaeea323
# 2023-03-20 07:05:00:  Creating job with filter_chars=58, JobRunId=jr_932c8ce6390281284633d206ee82ab64bf90b68eb64648196993a5a206888da2
# 2023-03-20 07:05:00:  Creating job with filter_chars=59, JobRunId=jr_1d7871c96b131c8ecae68746ac3bceb5789b5a53412527ea8011a31648202be5
# 2023-03-20 07:05:00:  Creating job with filter_chars=5a, JobRunId=jr_3e7db2113ae6b35903a8ae5f78e442a9350c5d700088365a4f5c3679292fc6ef
# 2023-03-20 07:05:00:  Creating job with filter_chars=5b, JobRunId=jr_938bfac133d87c0b7e8de6cfe620ae5a7c39b1de763467bf7aa1b36055ea9ebc
# 2023-03-20 07:05:00:  Creating job with filter_chars=5c, JobRunId=jr_d22d226d912f23bd3f48939d87a8640fb85f78120b4167f1df55dba91e9907e4
# 2023-03-20 07:05:00:  Counter({None: 163, 'SUCCEEDED': 77, 'RUNNING': 16})
# 2023-03-20 07:06:02:  Creating job with filter_chars=5d, JobRunId=jr_12dd47a5037774b28a02bb13328c97946f88af4376218acae5ba377d074df833
# 2023-03-20 07:06:02:  Creating job with filter_chars=5e, JobRunId=jr_9d093d72363111b5b0026f5f0b0c112ebce5f5bd05ff4c174e77297942dcf0cb
# 2023-03-20 07:06:02:  Counter({None: 161, 'SUCCEEDED': 79, 'RUNNING': 16})
# 2023-03-20 07:07:04:  Counter({None: 161, 'SUCCEEDED': 79, 'RUNNING': 16})
# 2023-03-20 07:08:06:  Counter({None: 161, 'SUCCEEDED': 79, 'RUNNING': 16})
# 2023-03-20 07:09:08:  Counter({None: 161, 'SUCCEEDED': 79, 'RUNNING': 16})
# 2023-03-20 07:10:10:  Creating job with filter_chars=5f, JobRunId=jr_d1c4bae68a8865089d3178e58ca45228e72901fdfb90079a805ed9ac054e82dc
# 2023-03-20 07:10:10:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:11:11:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:12:13:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:13:15:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:14:16:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:15:18:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:16:20:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:17:22:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:18:23:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:19:25:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:20:28:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:21:30:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:22:32:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:23:34:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:24:36:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:25:38:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:26:39:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:27:41:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:28:43:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:29:45:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:30:47:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:31:49:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:32:50:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:33:52:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:34:54:  Counter({None: 160, 'SUCCEEDED': 80, 'RUNNING': 16})
# 2023-03-20 07:35:56:  Creating job with filter_chars=60, JobRunId=jr_bebf359e751fc1bebd687194124e73454e8861ed5870a6caa2dde6643cedef78
# 2023-03-20 07:35:56:  Creating job with filter_chars=61, JobRunId=jr_8278dc65623ff85a8e8f1271c3913644f2897c74096940b6714e0dcdb6e6cce9
# 2023-03-20 07:35:56:  Counter({None: 158, 'SUCCEEDED': 82, 'RUNNING': 16})
# 2023-03-20 07:36:58:  Counter({None: 158, 'SUCCEEDED': 82, 'RUNNING': 16})
# 2023-03-20 07:37:59:  Creating job with filter_chars=62, JobRunId=jr_b7a80e6e830b15516dee17b5518a02ee473808ca9e0e4be8767d197d99f13b3c
# 2023-03-20 07:38:00:  Creating job with filter_chars=63, JobRunId=jr_79f0b871ad1f33b5e1ffb5a3baee3fd269697f18281d47a1c7176655465024a0
# 2023-03-20 07:38:00:  Creating job with filter_chars=64, JobRunId=jr_96baabd03d51753b8145e2d980b33be7e8d8ab1820c753aa747c4bde2410da1c
# 2023-03-20 07:38:00:  Counter({None: 155, 'SUCCEEDED': 85, 'RUNNING': 16})
# 2023-03-20 07:39:02:  Creating job with filter_chars=65, JobRunId=jr_c1919559cd1ac1dbd70158c7ed35617db393fc545616e544f2aa3a0303162f7d
# 2023-03-20 07:39:02:  Creating job with filter_chars=66, JobRunId=jr_9dcc936b85209410810da0c2c53f33a2c65671abf720f3385353a59957dd345a
# 2023-03-20 07:39:02:  Creating job with filter_chars=67, JobRunId=jr_adcab96b0f4b2eb2cc237da052b9971fd880cc28744770e310c4fbfbfc76c169
# 2023-03-20 07:39:02:  Creating job with filter_chars=68, JobRunId=jr_dd0e02d7fb6501f337d298713906ac30600edc35fab4e87c7acb28022bf596db
# 2023-03-20 07:39:02:  Creating job with filter_chars=69, JobRunId=jr_e8bd6220465a5178678c469b524b4b28c0c4bc1d3e450a9812d9afb63a431ecd
# 2023-03-20 07:39:03:  Creating job with filter_chars=6a, JobRunId=jr_4faf9478c2bf2b9fd82b7bda3ff2cfda174870fd09947394d7817830266a3c01
# 2023-03-20 07:39:03:  Creating job with filter_chars=6b, JobRunId=jr_8f82e35686bda642aeb44f9947fd2f1a062d6d290e7dc4c7d3d23d5fb246d306
# 2023-03-20 07:39:03:  Creating job with filter_chars=6c, JobRunId=jr_f5364d72d6b802381acc70a7406b15bb195ee7ce06e05597911fe1ce57022b72
# 2023-03-20 07:39:03:  Counter({None: 147, 'SUCCEEDED': 93, 'RUNNING': 16})
# 2023-03-20 07:40:05:  Creating job with filter_chars=6d, JobRunId=jr_f67e5023513d26f6e0fd489e563955ff630e4fb877d379d0f746dd3b7306f10d
# 2023-03-20 07:40:05:  Creating job with filter_chars=6e, JobRunId=jr_3e95d4c495b462ac9492a22d49824fad308e9892fc14e15672f067cf22d1126c
# 2023-03-20 07:40:05:  Counter({None: 145, 'SUCCEEDED': 95, 'RUNNING': 16})
# 2023-03-20 07:41:07:  Counter({None: 145, 'SUCCEEDED': 95, 'RUNNING': 16})
# 2023-03-20 07:42:08:  Counter({None: 145, 'SUCCEEDED': 95, 'RUNNING': 16})
# 2023-03-20 07:43:10:  Counter({None: 145, 'SUCCEEDED': 95, 'RUNNING': 16})
# 2023-03-20 07:44:12:  Creating job with filter_chars=6f, JobRunId=jr_ce45bf96908f963bff444a8c6a8e364c1e981593666830dcad233269779500a1
# 2023-03-20 07:44:12:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:45:14:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:46:16:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:47:18:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:48:19:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:49:22:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:50:23:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:51:26:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:52:28:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:53:29:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:54:31:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:55:33:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:56:35:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:57:36:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:58:38:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 07:59:40:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:00:41:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:01:43:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:02:46:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:03:48:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:04:50:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:05:51:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:06:53:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:07:55:  Counter({None: 144, 'SUCCEEDED': 96, 'RUNNING': 16})
# 2023-03-20 08:08:57:  Creating job with filter_chars=70, JobRunId=jr_71530b880acd282e7f0a050e66f1cdf0bfc58a492113ad07c3eba25774f0eb6f
# 2023-03-20 08:08:57:  Counter({None: 143, 'SUCCEEDED': 97, 'RUNNING': 16})
# 2023-03-20 08:09:59:  Creating job with filter_chars=71, JobRunId=jr_577339fb90be00575ba7a1cdc45fcf63f852e89f20e033632243cabc33022103
# 2023-03-20 08:09:59:  Counter({None: 142, 'SUCCEEDED': 98, 'RUNNING': 16})
# 2023-03-20 08:11:01:  Creating job with filter_chars=72, JobRunId=jr_f65a1d563b2a2b0a25c829eac8683bc7b7ba2b731a8df1c4eaabeba84abda3e9
# 2023-03-20 08:11:01:  Creating job with filter_chars=73, JobRunId=jr_bae02d4c3a3f8db7bd9609ae07fe5b3eb934d789a2b06d7d648475f8cf9f2333
# 2023-03-20 08:11:01:  Creating job with filter_chars=74, JobRunId=jr_a9f4d676973c8f7342e4c23c63b5cb4aec3ae027adf0648483c61db644e50c9a
# 2023-03-20 08:11:01:  Counter({None: 139, 'SUCCEEDED': 101, 'RUNNING': 16})
# 2023-03-20 08:12:03:  Creating job with filter_chars=75, JobRunId=jr_9b4dff4ea4014d70339cb3fb88bbba927902d4f1363d2c41284687d5f455457c
# 2023-03-20 08:12:03:  Creating job with filter_chars=76, JobRunId=jr_467b14ac90b0268090139de1dc0c3910967c17af0936c7ed4408eb5b1f4f806d
# 2023-03-20 08:12:03:  Counter({None: 137, 'SUCCEEDED': 103, 'RUNNING': 16})
# 2023-03-20 08:13:05:  Creating job with filter_chars=77, JobRunId=jr_3ec598081861515fa7374376cd752a8a6ba3357bda872875e043bae332e3f7c4
# 2023-03-20 08:13:05:  Creating job with filter_chars=78, JobRunId=jr_de1220a97cbe969624b0abe963625a7653adac44ef1d801331bf067be225db34
# 2023-03-20 08:13:06:  Creating job with filter_chars=79, JobRunId=jr_d7f486f89f194e8a41569c1312869e1c8f0940ac4dd12bfef521520ef50abf5d
# 2023-03-20 08:13:06:  Creating job with filter_chars=7a, JobRunId=jr_f7cf27e9f57a4c5236b46e293120b2813038e762b0c72d1d6b9d654754000ce9
# 2023-03-20 08:13:06:  Creating job with filter_chars=7b, JobRunId=jr_43d81764840913398681edbd8dca617fb78b12e3e42358d91dbe4a6476a63644
# 2023-03-20 08:13:06:  Creating job with filter_chars=7c, JobRunId=jr_33699e2b530ede44e9c7a60cc80923fefab0fad9423fa8d8446fb0917d88ec35
# 2023-03-20 08:13:06:  Creating job with filter_chars=7d, JobRunId=jr_2f252b0906e9319f40494e9271a7ded12fd7bb16ee72a5eed365d7b202512fd4
# 2023-03-20 08:13:06:  Counter({None: 130, 'SUCCEEDED': 110, 'RUNNING': 16})
# 2023-03-20 08:14:08:  Creating job with filter_chars=7e, JobRunId=jr_48e4fdd2f7e70319ec1a665a3892dc3da0e3ab754e7c0a382ae1e39bff43abff
# 2023-03-20 08:14:08:  Counter({None: 129, 'SUCCEEDED': 111, 'RUNNING': 16})
# 2023-03-20 08:15:10:  Counter({None: 129, 'SUCCEEDED': 111, 'RUNNING': 16})
# 2023-03-20 08:16:12:  Counter({None: 129, 'SUCCEEDED': 111, 'RUNNING': 16})
# 2023-03-20 08:17:14:  Counter({None: 129, 'SUCCEEDED': 111, 'RUNNING': 16})
# 2023-03-20 08:18:16:  Counter({None: 129, 'SUCCEEDED': 111, 'RUNNING': 16})
# 2023-03-20 08:19:17:  Creating job with filter_chars=7f, JobRunId=jr_b3fb6a124c50508e6b17a68714d828dfb1c6b2a9fc7b55b01ae79ec1b7bb6ef9
# 2023-03-20 08:19:17:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:20:19:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:21:21:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:22:23:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:23:24:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:24:26:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:25:28:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:26:31:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:27:33:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:28:34:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:29:36:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:30:38:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:31:40:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:32:42:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:33:43:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:34:45:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:35:47:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:36:49:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:37:51:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:38:53:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:39:54:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:40:56:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:41:58:  Counter({None: 128, 'SUCCEEDED': 112, 'RUNNING': 16})
# 2023-03-20 08:43:00:  Creating job with filter_chars=80, JobRunId=jr_905c52287e4743496f41a078b779cd9f286a57a50af7d79bb9c940505708ee34
# 2023-03-20 08:43:00:  Counter({None: 127, 'SUCCEEDED': 113, 'RUNNING': 16})
# 2023-03-20 08:44:02:  Creating job with filter_chars=81, JobRunId=jr_83fe17209d5ad363e19efb8c428818049e221602833dd47c82f1c1ab7f311ef8
# 2023-03-20 08:44:02:  Counter({None: 126, 'SUCCEEDED': 114, 'RUNNING': 16})
# 2023-03-20 08:45:04:  Creating job with filter_chars=82, JobRunId=jr_7ce183eef6227e3f8d80fcd6eae83f4883e39e6321eb46d30dca75df30db710c
# 2023-03-20 08:45:04:  Creating job with filter_chars=83, JobRunId=jr_ebc217009c037e3c0bd0cc897d93e86582264f904249ab78b29c0202d693f1af
# 2023-03-20 08:45:04:  Creating job with filter_chars=84, JobRunId=jr_7216180583ae66def0133551b69f2526298f837fb73c09cf03d0f7a3503a5972
# 2023-03-20 08:45:04:  Counter({None: 123, 'SUCCEEDED': 117, 'RUNNING': 16})
# 2023-03-20 08:46:07:  Creating job with filter_chars=85, JobRunId=jr_8bbd043794a07e203795d7fb7cf0da885293b78f664b727ff77c1396cf279702
# 2023-03-20 08:46:07:  Creating job with filter_chars=86, JobRunId=jr_57d7840d0ad0382fccc3976ff5ed11bef60cbade128e4d927e536ff72118a06d
# 2023-03-20 08:46:07:  Counter({None: 121, 'SUCCEEDED': 119, 'RUNNING': 16})
# 2023-03-20 08:47:09:  Creating job with filter_chars=87, JobRunId=jr_634a0a54c68dfc7c08be86cf5c8261a883970af30f6824c2032c71c614513878
# 2023-03-20 08:47:09:  Creating job with filter_chars=88, JobRunId=jr_7ea11fa59a1b73cf612c71739b6fd5600f054a9a36a14eacc0b1210e18ae3ee4
# 2023-03-20 08:47:09:  Creating job with filter_chars=89, JobRunId=jr_2eff519282a3a66ba07338271202a984b55436e606add767715554d2ba5e5486
# 2023-03-20 08:47:09:  Creating job with filter_chars=8a, JobRunId=jr_94b97fab750e43e27fd76e9e4579a206c84d1f8a77a7583c4c2ede00f13eddb9
# 2023-03-20 08:47:09:  Creating job with filter_chars=8b, JobRunId=jr_478caaa878da51b1d840fcbf700a6d24526573720beda47ee41197d789336774
# 2023-03-20 08:47:09:  Creating job with filter_chars=8c, JobRunId=jr_247fa8b9a34324c8f77bbfc157a9b5657e65c3190ef9bc08867e02f5a955fb4c
# 2023-03-20 08:47:09:  Counter({'SUCCEEDED': 125, None: 115, 'RUNNING': 16})
# 2023-03-20 08:48:11:  Creating job with filter_chars=8d, JobRunId=jr_96a33b57b724c7442bbcc33efe5e2d90d12cb994d7ea30168847be8dccfc85db
# 2023-03-20 08:48:11:  Counter({'SUCCEEDED': 126, None: 114, 'RUNNING': 16})
# 2023-03-20 08:49:13:  Creating job with filter_chars=8e, JobRunId=jr_183b7576c523a5aa522d7e885f9857ab9b135638f25bed29a96fc57d84db97ae
# 2023-03-20 08:49:13:  Counter({'SUCCEEDED': 127, None: 113, 'RUNNING': 16})
# 2023-03-20 08:50:15:  Counter({'SUCCEEDED': 127, None: 113, 'RUNNING': 16})
# 2023-03-20 08:51:17:  Counter({'SUCCEEDED': 127, None: 113, 'RUNNING': 16})
# 2023-03-20 08:52:19:  Counter({'SUCCEEDED': 127, None: 113, 'RUNNING': 16})
# 2023-03-20 08:53:20:  Counter({'SUCCEEDED': 127, None: 113, 'RUNNING': 16})
# 2023-03-20 08:54:22:  Creating job with filter_chars=8f, JobRunId=jr_dfb35a4a4dd715fe57837adad25db78483da9862d7eebce8350ab820bb8662d7
# 2023-03-20 08:54:22:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 08:55:24:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 08:56:26:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 08:57:28:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 08:58:29:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 08:59:31:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:00:33:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:01:36:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:02:37:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:03:39:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:04:41:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:05:43:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:06:45:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:07:47:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:08:49:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:09:51:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:10:53:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:11:54:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:12:56:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:13:58:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:15:00:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:16:01:  Counter({'SUCCEEDED': 128, None: 112, 'RUNNING': 16})
# 2023-03-20 09:17:04:  Creating job with filter_chars=90, JobRunId=jr_f9bccba163e9594947f48a579b9b494c4a8148ba6647f55c2fb4dc70999ee2a8
# 2023-03-20 09:17:04:  Counter({'SUCCEEDED': 129, None: 111, 'RUNNING': 16})
# 2023-03-20 09:18:06:  Counter({'SUCCEEDED': 129, None: 111, 'RUNNING': 16})
# 2023-03-20 09:19:07:  Creating job with filter_chars=91, JobRunId=jr_6cf1b052946e85d7b374ef14be9392f7f77ce8fb29e464714653f47a39ed49ac
# 2023-03-20 09:19:08:  Creating job with filter_chars=92, JobRunId=jr_1e1452b528b4238e68d2238a5df07ee9ce9935c80028370f31faf130031ebf79
# 2023-03-20 09:19:08:  Creating job with filter_chars=93, JobRunId=jr_074e5bef6d6dedf5c95a51327424f54376abbfb7aba78bbee5d3e2e820303a46
# 2023-03-20 09:19:08:  Creating job with filter_chars=94, JobRunId=jr_cc933fd5ab21191abfa50dd3c42f6aee0bbc2ea71f884f47278d6818d65b19e8
# 2023-03-20 09:19:08:  Counter({'SUCCEEDED': 133, None: 107, 'RUNNING': 16})
# 2023-03-20 09:20:10:  Creating job with filter_chars=95, JobRunId=jr_52775a47ec9bbe7e397350fdbb8df947bb569e08ad5dec4a3936333e5b3e60ac
# 2023-03-20 09:20:10:  Creating job with filter_chars=96, JobRunId=jr_0407d31e5000e17d6e80738cf4aa7b36e9d532560fc95bde477a0c424a8727d1
# 2023-03-20 09:20:10:  Counter({'SUCCEEDED': 135, None: 105, 'RUNNING': 16})
# 2023-03-20 09:21:12:  Creating job with filter_chars=97, JobRunId=jr_b55df63d0eb3e51f5dc167dfe4955ed510d8677eb7e4fa43afd1ef755cc3cfb7
# 2023-03-20 09:21:12:  Creating job with filter_chars=98, JobRunId=jr_f2ec3c5085427018cb31f35badf59a11b097b91a9c2496a2fa4b93c910261a6c
# 2023-03-20 09:21:13:  Creating job with filter_chars=99, JobRunId=jr_6ad6f9606c15e2f1c8d827cf44beb7d1f55a13411697e7de73a4cc67dfbc4af0
# 2023-03-20 09:21:13:  Creating job with filter_chars=9a, JobRunId=jr_428838ff3ac2e55ed6efc7c24de18ce7ea27cbeb4350f7084fcfb530cdae6570
# 2023-03-20 09:21:13:  Creating job with filter_chars=9b, JobRunId=jr_41ac97c553284842cab9a8184e493a98e2efc99f2af3f4b9fa51220082f9ef49
# 2023-03-20 09:21:13:  Creating job with filter_chars=9c, JobRunId=jr_2496311dc7ab728d48b95ac13034a6c4df9b126f70c8faae5d309dd67acac699
# 2023-03-20 09:21:13:  Counter({'SUCCEEDED': 141, None: 99, 'RUNNING': 16})
# 2023-03-20 09:22:16:  Creating job with filter_chars=9d, JobRunId=jr_46ad6382893f1b5ba8c28a3c4c44efc3f92eed959e0757ca2e438827e9df1a6f
# 2023-03-20 09:22:16:  Counter({'SUCCEEDED': 142, None: 98, 'RUNNING': 16})
# 2023-03-20 09:23:19:  Creating job with filter_chars=9e, JobRunId=jr_d5d8f79c4a64c2664993ffadf8534b265934d41825a3abddb2064795aa12b175
# 2023-03-20 09:23:19:  Counter({'SUCCEEDED': 143, None: 97, 'RUNNING': 16})
# 2023-03-20 09:24:21:  Counter({'SUCCEEDED': 143, None: 97, 'RUNNING': 16})
# 2023-03-20 09:25:23:  Counter({'SUCCEEDED': 143, None: 97, 'RUNNING': 16})
# 2023-03-20 09:26:25:  Counter({'SUCCEEDED': 143, None: 97, 'RUNNING': 16})
# 2023-03-20 09:27:26:  Counter({'SUCCEEDED': 143, None: 97, 'RUNNING': 16})
# 2023-03-20 09:28:28:  Creating job with filter_chars=9f, JobRunId=jr_6f0582705dac2e1573d4c5d96ac03ed86058a123a2271d453876b0c225d9928e
# 2023-03-20 09:28:28:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:29:30:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:30:32:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:31:34:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:32:36:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:33:38:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:34:40:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:35:42:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:36:44:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:37:45:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:38:47:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:39:49:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:40:51:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:41:53:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:42:54:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:43:56:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:44:58:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:46:00:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:47:02:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:48:04:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:49:06:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:50:08:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:51:09:  Counter({'SUCCEEDED': 144, None: 96, 'RUNNING': 16})
# 2023-03-20 09:52:11:  Creating job with filter_chars=a0, JobRunId=jr_bc0bc811f7e5f5a0b4530c14aebf8e7213ff82e3a1da5d2aa3047afdfa67d0e2
# 2023-03-20 09:52:11:  Counter({'SUCCEEDED': 145, None: 95, 'RUNNING': 16})
# 2023-03-20 09:53:13:  Creating job with filter_chars=a1, JobRunId=jr_c504cb138af8bff83af4c7183152e6d9d8de79ed8a6ed18bee1156b3c90ee1d1
# 2023-03-20 09:53:13:  Creating job with filter_chars=a2, JobRunId=jr_a047c6f6fe44c76b30a65279220d413fc2e2f2499de671dc6da10b4ab8d603a1
# 2023-03-20 09:53:13:  Counter({'SUCCEEDED': 147, None: 93, 'RUNNING': 16})
# 2023-03-20 09:54:15:  Creating job with filter_chars=a3, JobRunId=jr_bf32db510707eb4d1605e6da66e7b8577962d18379f4dfc6d92deef96c16b9f0
# 2023-03-20 09:54:16:  Creating job with filter_chars=a4, JobRunId=jr_f253d8bea046060bf4451f22e0be443f949e70bff9077d8b27b8399d172c25a7
# 2023-03-20 09:54:16:  Creating job with filter_chars=a5, JobRunId=jr_9b96f56f520518e53c8355643165cb77010813b9f9849ab221bd02f724d2ae95
# 2023-03-20 09:54:16:  Creating job with filter_chars=a6, JobRunId=jr_530a0a048f370f0b028b8cebd1f1ab1f26d7a6ada433aa93360baefcd4706a79
# 2023-03-20 09:54:16:  Counter({'SUCCEEDED': 151, None: 89, 'RUNNING': 16})
# 2023-03-20 09:55:18:  Creating job with filter_chars=a7, JobRunId=jr_2386df30f898b9d34356999d20ae3d2072f73c40dd192a3d5e1d7bf43419ad45
# 2023-03-20 09:55:18:  Creating job with filter_chars=a8, JobRunId=jr_20d2ec92fca790bb09c0e5446fde403406e2893a37766f9e18f90fc4ea17f8e6
# 2023-03-20 09:55:18:  Creating job with filter_chars=a9, JobRunId=jr_6b563988aa8732f819b2df0bdaaad3bc09ebee25be7a9e2c837815dbf9190ee6
# 2023-03-20 09:55:18:  Creating job with filter_chars=aa, JobRunId=jr_850afb20d13e5c218634a7c716fd89d82faadd0ba16973d14cec687708e5e949
# 2023-03-20 09:55:18:  Creating job with filter_chars=ab, JobRunId=jr_2ed61f79aa466a155eadc5458d573e817ab97f070211556a11fdb7a9620cd50f
# 2023-03-20 09:55:18:  Counter({'SUCCEEDED': 156, None: 84, 'RUNNING': 16})
# 2023-03-20 09:56:20:  Creating job with filter_chars=ac, JobRunId=jr_801cef3b279a56b35844cf418acbe977d7655cb7f773897c74100b1f7cb04a5e
# 2023-03-20 09:56:20:  Creating job with filter_chars=ad, JobRunId=jr_6bfbd2fd2d3c9459560083c695b73cb0b1c61742a66a1adefbcf99e1b195a2de
# 2023-03-20 09:56:20:  Counter({'SUCCEEDED': 158, None: 82, 'RUNNING': 16})
# 2023-03-20 09:57:22:  Counter({'SUCCEEDED': 158, None: 82, 'RUNNING': 16})
# 2023-03-20 09:58:24:  Creating job with filter_chars=ae, JobRunId=jr_69b19b96ae86452483a9b90e6492558d2abbab3eba7f6d23effe7184763f73e7
# 2023-03-20 09:58:24:  Counter({'SUCCEEDED': 159, None: 81, 'RUNNING': 16})
# 2023-03-20 09:59:26:  Counter({'SUCCEEDED': 159, None: 81, 'RUNNING': 16})
# 2023-03-20 10:00:28:  Counter({'SUCCEEDED': 159, None: 81, 'RUNNING': 16})
# 2023-03-20 10:01:30:  Counter({'SUCCEEDED': 159, None: 81, 'RUNNING': 16})
# 2023-03-20 10:02:32:  Counter({'SUCCEEDED': 159, None: 81, 'RUNNING': 16})
# 2023-03-20 10:03:34:  Creating job with filter_chars=a7, JobRunId=jr_2720fa0a290c162340b7356f7aed6c685900097aa6bd941ab6ede86d6ca0cdf5
# 2023-03-20 10:03:35:  Creating job with filter_chars=af, JobRunId=jr_da700d4c22d356d15af83ec89222d0ae6fae567ab9aa4e9ce92bec341475a351
# 2023-03-20 10:03:35:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:04:37:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:05:38:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:06:40:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:07:42:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:08:44:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:09:46:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:10:48:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:11:50:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:12:52:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:13:54:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:14:56:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:15:58:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:17:00:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:18:01:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:19:03:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:20:05:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:21:07:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:22:09:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:23:11:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:24:13:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:25:16:  Counter({'SUCCEEDED': 160, None: 80, 'RUNNING': 16})
# 2023-03-20 10:26:18:  Creating job with filter_chars=b0, JobRunId=jr_888d273ddc05aea92f3697fbc31be1c150dbac47949787af4f36b1534b4e2164
# 2023-03-20 10:26:18:  Counter({'SUCCEEDED': 161, None: 79, 'RUNNING': 16})
# ...
# 2023-03-20 12:11:36:  Creating job with filter_chars=e1, JobRunId=jr_5c1085fd5dd8a968f30b340b29425bd27055da0860d42b54bc016c91f5a61821
# 2023-03-20 12:11:36:  Creating job with filter_chars=e2, JobRunId=jr_0fba38dc1cd89a5bafadc9d10b9278b8cfd68c53eecdffa8a73cb01ab5f13f2f
# 2023-03-20 12:11:36:  Creating job with filter_chars=e3, JobRunId=jr_d7335bf8a3751e1d623d12f0f1cfcdb4af184d975e2ddb323749de91838f7709
# 2023-03-20 12:11:37:  Creating job with filter_chars=e4, JobRunId=jr_54e98d064527db1ec0d6205beaf66542f10c91c49e95b16ede5a713eb4fd2914
# 2023-03-20 12:11:37:  Counter({'SUCCEEDED': 213, None: 27, 'RUNNING': 16})
# 2023-03-20 12:12:39:  Creating job with filter_chars=cb, JobRunId=jr_2c3e6228a94cc006b9ffc2c445918ffd7f0514d2588c8ac1623320aa3769314e
# 2023-03-20 12:12:39:  Creating job with filter_chars=e5, JobRunId=jr_234b88a47738591b69d83e21ccefd856a595395ebf8421547bb170bb0f167f6b
# 2023-03-20 12:12:39:  Creating job with filter_chars=e6, JobRunId=jr_58d42472945b72980daf7430ab0787f55953ae1b3e5b7ec4fa3f644b14892c8f
# 2023-03-20 12:12:39:  Creating job with filter_chars=e7, JobRunId=jr_8ffee851729870de3752adf8caa5eaa50947879ccc4e77b38531b07489137cbf
# 2023-03-20 12:12:39:  Counter({'SUCCEEDED': 216, None: 24, 'RUNNING': 16})
# 2023-03-20 12:13:41:  Creating job with filter_chars=e8, JobRunId=jr_d131d89479322b7c33452e143786268e3b78af6919d1d06fa48cf95bdd5222d8
# 2023-03-20 12:13:41:  Counter({'SUCCEEDED': 217, None: 23, 'RUNNING': 16})
# 2023-03-20 12:14:43:  Creating job with filter_chars=e9, JobRunId=jr_8dc992072a3a4fc652438314a26dcea181797218354b0d43719f8a28161429eb
# 2023-03-20 12:14:43:  Counter({'SUCCEEDED': 218, None: 22, 'RUNNING': 16})
# 2023-03-20 12:15:45:  Counter({'SUCCEEDED': 218, None: 22, 'RUNNING': 16})
# 2023-03-20 12:16:47:  Creating job with filter_chars=ea, JobRunId=jr_fb6eb849435980cc8dbf2395ea319213013edd82523d066899b94f14adabf108
# 2023-03-20 12:16:47:  Creating job with filter_chars=eb, JobRunId=jr_341f0852910c9555a195edfa4c5d99104ba21a9a5b195c6c2b7dde009c6d9632
# 2023-03-20 12:16:47:  Counter({'SUCCEEDED': 220, None: 20, 'RUNNING': 16})
# 2023-03-20 12:17:48:  Counter({'SUCCEEDED': 220, None: 20, 'RUNNING': 16})
# 2023-03-20 12:18:50:  Counter({'SUCCEEDED': 220, None: 20, 'RUNNING': 16})
# 2023-03-20 12:19:53:  Counter({'SUCCEEDED': 220, None: 20, 'RUNNING': 16})
# 2023-03-20 12:20:55:  Creating job with filter_chars=cb, JobRunId=jr_b59f05ee3ad6673398c429215ea3153db2a0aafe2224905d4981e36bd8d490c2
# 2023-03-20 12:20:55:  Creating job with filter_chars=ec, JobRunId=jr_c1d0145912da46d4fec2631ddb596c761dc7990b0de436111e5dbbeb75d88ff4
# 2023-03-20 12:20:55:  Counter({'SUCCEEDED': 221, None: 19, 'RUNNING': 16})
# 2023-03-20 12:21:57:  Counter({'SUCCEEDED': 221, None: 19, 'RUNNING': 16})
# 2023-03-20 12:22:59:  Creating job with filter_chars=ed, JobRunId=jr_6f179aa351b38af9beaa198d71eddb7d891ecc4fc5935129274c9e4db76a439d
# 2023-03-20 12:22:59:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:24:00:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:25:02:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:26:04:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:27:06:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:28:08:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:29:10:  Creating job with filter_chars=cb, JobRunId=jr_d054d4b83ff7e2e2bcf53b9809cb77b28c56ee746bd31c8cac2cece243a05719
# 2023-03-20 12:29:10:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:30:12:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:31:14:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:32:16:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:33:18:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:34:20:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:35:22:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:36:24:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:37:26:  Creating job with filter_chars=cb, JobRunId=jr_92e4db72849b45460c0aebf7b0836ccb5e63fb1cf84d75cb518f61efafa6fa11
# 2023-03-20 12:37:26:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:38:28:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:39:30:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:40:31:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:41:33:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:42:35:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:43:37:  Counter({'SUCCEEDED': 222, None: 18, 'RUNNING': 16})
# 2023-03-20 12:44:39:  Creating job with filter_chars=ee, JobRunId=jr_a038f2dc382fe76b726d27f7f47a94031388a129470a7f23d29a7863d7f4b322
# 2023-03-20 12:44:39:  Counter({'SUCCEEDED': 223, None: 17, 'RUNNING': 16})
# 2023-03-20 12:45:41:  Creating job with filter_chars=cb, JobRunId=jr_b82fccf34c93d1dfbcaf90f2f685faad6e46226031b42f6ba6d73f11234092f3
# 2023-03-20 12:45:41:  Creating job with filter_chars=ef, JobRunId=jr_4b213784da03274b3a90638b92ff333224fd0a4003adc626495f0ba18176b9f3
# 2023-03-20 12:45:41:  Counter({'SUCCEEDED': 224, 'RUNNING': 16, None: 16})
# 2023-03-20 12:46:43:  Creating job with filter_chars=f0, JobRunId=jr_973f4ac0e06444a9c005a3aedb47e2fe8fff3d6e5ac520ef707e3762ebcf52ad
# 2023-03-20 12:46:43:  Creating job with filter_chars=f1, JobRunId=jr_e10131ce075d50e0ce42b3a7e8010dfd4eca5db2efdce3d73afe6207f27afa2c
# 2023-03-20 12:46:43:  Creating job with filter_chars=f2, JobRunId=jr_62ba4f670a38a6fa26818173bf5207a1c28525eaccfe671c84b165366a59dc39
# 2023-03-20 12:46:44:  Creating job with filter_chars=f3, JobRunId=jr_29be90a0b5a42073b5982af4db2f14418407c6891b05d5cdbb329932a8a1d306
# 2023-03-20 12:46:44:  Creating job with filter_chars=f4, JobRunId=jr_55d88368c3025f8c949018441e474b0d0efe8ce6ce0f9814c33a4ee67fc612b5
# 2023-03-20 12:46:44:  Counter({'SUCCEEDED': 229, 'RUNNING': 16, None: 11})
# 2023-03-20 12:47:46:  Creating job with filter_chars=f5, JobRunId=jr_6c1d8acd374c64f9eee85cb0af695bedceb01702c3c4c69d06bcf53f78ffcfcf
# 2023-03-20 12:47:46:  Creating job with filter_chars=f6, JobRunId=jr_88fbe27651de831045579aecbba0803d558be700b8140ba0b072ee5b3c2f3f56
# 2023-03-20 12:47:46:  Counter({'SUCCEEDED': 231, 'RUNNING': 16, None: 9})
# 2023-03-20 12:48:48:  Creating job with filter_chars=f7, JobRunId=jr_6f89e29cb5e62c800a52cd621abdf941d36fc1cdd897fa4d56480188c9125ed9
# 2023-03-20 12:48:48:  Counter({'SUCCEEDED': 232, 'RUNNING': 16, None: 8})
# 2023-03-20 12:49:49:  Creating job with filter_chars=f8, JobRunId=jr_3184ec9482fccaef292315c86d893c9b3575850f70c4ef291a67aa3d656517f5
# 2023-03-20 12:49:49:  Counter({'SUCCEEDED': 233, 'RUNNING': 16, None: 7})
# 2023-03-20 12:50:51:  Counter({'SUCCEEDED': 233, 'RUNNING': 16, None: 7})
# 2023-03-20 12:51:53:  Creating job with filter_chars=f9, JobRunId=jr_e12f41a72da9ffd055d956a8fe37ea20b640ff54845a799f732b548658797863
# 2023-03-20 12:51:53:  Creating job with filter_chars=fa, JobRunId=jr_3619b45fcfc304684a02c8bcd0b3eb166315e40e6ac249a8d9bd16f1b0827d18
# 2023-03-20 12:51:53:  Counter({'SUCCEEDED': 235, 'RUNNING': 16, None: 5})
# 2023-03-20 12:52:55:  Counter({'SUCCEEDED': 235, 'RUNNING': 16, None: 5})
# 2023-03-20 12:53:57:  Creating job with filter_chars=cb, JobRunId=jr_3008f3b9f798756ee918712cf47e645fc29038685c02475cdd9c4a625a9204d5
# 2023-03-20 12:53:57:  Counter({'SUCCEEDED': 235, 'RUNNING': 16, None: 5})
# 2023-03-20 12:54:59:  Creating job with filter_chars=fb, JobRunId=jr_a2aec38272c931c2a4592c7f36e7099d0f7e023b3456bb3ac6f85b0d4f858f13
# 2023-03-20 12:54:59:  Counter({'SUCCEEDED': 236, 'RUNNING': 16, None: 4})
# 2023-03-20 12:56:02:  Counter({'SUCCEEDED': 236, 'RUNNING': 16, None: 4})
# 2023-03-20 12:57:04:  Counter({'SUCCEEDED': 236, 'RUNNING': 16, None: 4})
# 2023-03-20 12:58:06:  Creating job with filter_chars=fc, JobRunId=jr_7ee46d386ede6e7c39fc320283aac99c212aa2107a8a8d8a6c1d9153ff4bd7ad
# 2023-03-20 12:58:06:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 12:59:08:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:00:10:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:01:12:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:02:14:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:03:16:  Creating job with filter_chars=cb, JobRunId=jr_d15a1f3d215d199e38e24b76a78a4b8b2d40aeedd128dea4c0d347c591eb4c7e
# 2023-03-20 13:03:16:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:04:17:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:05:19:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:06:21:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:07:23:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:08:25:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:09:27:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:10:29:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:11:30:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:12:32:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:13:34:  Creating job with filter_chars=cb, JobRunId=jr_a6b544b4c30d0507753404dfd7e1071786db291b6fb0e288de499d9c359aba06
# 2023-03-20 13:13:34:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:14:36:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:15:38:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:16:40:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:17:42:  Counter({'SUCCEEDED': 237, 'RUNNING': 16, None: 3})
# 2023-03-20 13:18:44:  Creating job with filter_chars=fd, JobRunId=jr_8bd04fb4f3fdb1be24f01755a96c2881c48d37b1215d1b6f865aa9e9857a2309
# 2023-03-20 13:18:44:  Counter({'SUCCEEDED': 238, 'RUNNING': 16, None: 2})
# 2023-03-20 13:19:46:  Creating job with filter_chars=fe, JobRunId=jr_931d78cdcbf16b8877dd00c914c74df11ff81ab0f2496dc37e37381e32910da2
# 2023-03-20 13:19:46:  Counter({'SUCCEEDED': 239, 'RUNNING': 16, None: 1})
# 2023-03-20 13:20:48:  Creating job with filter_chars=ff, JobRunId=jr_4d594dc7ba608625e2a7e970d3cb1579d4f106ddd15aaa7155ec928b332bac0b
# 2023-03-20 13:20:48:  Counter({'SUCCEEDED': 241, 'RUNNING': 15})
# 2023-03-20 13:21:50:  Creating job with filter_chars=cb, JobRunId=jr_bbf343d4662f50334646f086af1f04a2716d34e87d1ac428447bfb719ae511cc
# 2023-03-20 13:21:50:  Counter({'SUCCEEDED': 245, 'RUNNING': 11})
# 2023-03-20 13:22:51:  Counter({'SUCCEEDED': 246, 'RUNNING': 10})
# 2023-03-20 13:23:52:  Counter({'SUCCEEDED': 247, 'RUNNING': 9})
# 2023-03-20 13:24:54:  Counter({'SUCCEEDED': 248, 'RUNNING': 8})
# 2023-03-20 13:25:55:  Counter({'SUCCEEDED': 249, 'RUNNING': 7})
# 2023-03-20 13:26:55:  Counter({'SUCCEEDED': 250, 'RUNNING': 6})
# 2023-03-20 13:27:56:  Counter({'SUCCEEDED': 250, 'RUNNING': 6})
# 2023-03-20 13:28:57:  Counter({'SUCCEEDED': 250, 'RUNNING': 6})
# 2023-03-20 13:29:58:  Creating job with filter_chars=cb, JobRunId=jr_89bca63596a32e9f56cc860838b86b844333f699a8a9a07b7137f9366c54d110
# 2023-03-20 13:29:58:  Counter({'SUCCEEDED': 251, 'RUNNING': 5})
# 2023-03-20 13:30:59:  Counter({'SUCCEEDED': 251, 'RUNNING': 5})
# 2023-03-20 13:32:00:  Counter({'SUCCEEDED': 251, 'RUNNING': 5})
# 2023-03-20 13:33:00:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:34:01:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:35:02:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:36:02:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:37:03:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:38:04:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:39:05:  Creating job with filter_chars=cb, JobRunId=jr_9bafdc124304d9fb4567cbe0b6d20c1bdb0f951d0e355636deb577bbc174bd73
# 2023-03-20 13:39:05:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:40:06:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:41:07:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:42:08:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:43:09:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:44:09:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:45:10:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:46:11:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:47:12:  Creating job with filter_chars=cb, JobRunId=jr_b0ecd852f347ae6288868762400c12d77e789da23a9a90aeaa7438b59ea4e0e2
# 2023-03-20 13:47:12:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:48:12:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:49:13:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:50:13:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:51:14:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:52:15:  Counter({'SUCCEEDED': 252, 'RUNNING': 4})
# 2023-03-20 13:53:15:  Counter({'SUCCEEDED': 253, 'RUNNING': 3})
# 2023-03-20 13:54:16:  Counter({'SUCCEEDED': 254, 'RUNNING': 2})
# 2023-03-20 13:55:16:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 13:56:17:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 13:57:17:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 13:58:18:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 13:59:18:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:00:18:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:01:19:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:02:19:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:03:20:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:04:20:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:05:20:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:06:21:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:07:21:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:08:22:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:09:22:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:10:22:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:11:23:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:12:23:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:13:23:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:14:24:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:15:24:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:16:25:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:17:25:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:18:25:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:19:26:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:20:26:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# 2023-03-20 14:21:27:  Counter({'SUCCEEDED': 255, 'RUNNING': 1})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_154552\2289625083.py in <module>
#      37     time.sleep(60)
#      38
# ---> 39 status_summary = Counter(d['JobRunState'] for d in run_status.values())
#      40 logmsg(status_summary)
#      41 logmsg01('Process complete')
#
# c:\Users\HERZOMJ\Anaconda3\envs\GUIAutomation\lib\collections\__init__.py in __init__(self, iterable, **kwds)
#     550         '''
#     551         super(Counter, self).__init__()
# --> 552         self.update(iterable, **kwds)
#     553
#     554     def __missing__(self, key):
#
# c:\Users\HERZOMJ\Anaconda3\envs\GUIAutomation\lib\collections\__init__.py in update(self, iterable, **kwds)
#     635                     super(Counter, self).update(iterable) # fast path when counter is empty
#     636             else:
# --> 637                 _count_elements(self, iterable)
#     638         if kwds:
#     639             self.update(kwds)
#
# ~\AppData\Local\Temp\ipykernel_154552\2289625083.py in <genexpr>(.0)
#      37     time.sleep(60)
#      38
# ---> 39 status_summary = Counter(d['JobRunState'] for d in run_status.values())
#      40 logmsg(status_summary)
#      41 logmsg01('Process complete')
#
# TypeError: string indices must be integers

# %%
# Out:
# Counter({'SUCCEEDED': 256})
# 2023-03-20 14:59:25:  Process complete
